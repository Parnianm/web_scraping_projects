# %%
import time   # Import time module for delays
import json   # Import JSON module for handling cookies
import random  # Import random module to select user agents
import asyncio  # Import asyncio for async execution
import nest_asyncio  # Import nest_asyncio to allow nested async loops
from selenium import webdriver  # Import Selenium WebDriver
from selenium.webdriver.common.by import By  # Import By class for locating elements
from selenium.webdriver.chrome.service import Service  # Import Service for ChromeDriver
from selenium.webdriver.chrome.options import Options  # Import Options to configure WebDriver
from selenium.webdriver.support.ui import WebDriverWait   # Import WebDriverWait for explicit waits
from selenium.webdriver.support import expected_conditions as EC  # Import expected_conditions for conditions
import pandas as pd  # Import pandas for handling and saving extracted data

# %%
# ============================
# 🟡 Helper Function: Setup WebDriver
# ============================
def setup_driver():
    """
    Initializes and configures Selenium WebDriver with performance optimizations.
    """
    user_agents = [  # List of user agents to avoid detection
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64)",
        "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7)",
        "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:94.0)",
    ]
    
    chrome_options = Options()  # Create Chrome options object
     # Running in headless mode for efficiency (Uncomment if needed)
    # chrome_options.add_argument('--headless')  # Run browser in headless mode
    chrome_options.add_argument('--disable-blink-features=AutomationControlled') # Bypass automation detection
    chrome_options.add_argument(f'--user-agent={random.choice(user_agents)}')  # Randomize user-agent
    chrome_options.add_argument('--start-maximized') # Open browser in maximized mode
    chrome_options.add_argument('--disable-gpu')  # Disable GPU acceleration for stability
    chrome_options.add_argument('--log-level=3')  # Suppress unnecessary logs
    chrome_options.add_argument('--ignore-certificate-errors')  # Ignore SSL errors
    chrome_options.add_experimental_option("excludeSwitches", ["enable-automation"])  # Disable automation flags
    
    chrome_service = Service(executable_path="C:/Users/parni/OneDrive/Desktop/ebayScraper/ebay_scraper/chromedriver-win64/chromedriver.exe")
    driver = webdriver.Chrome(service=chrome_service, options=chrome_options) # Initialize WebDriver with options
    return driver   # Return the configured WebDriver instance

# %%
# ============================
# 🟡 Function: Save & Load Cookies
# ============================
def save_cookies(driver, filename="cookies.json"):
    """ Saves cookies to a JSON file. """
    with open(filename, "w") as file:
        json.dump(driver.get_cookies(), file)
    print("✅ Cookies saved.")

def load_cookies(driver, filename="cookies.json"):
    """ Loads cookies from a JSON file. """
    try:
        with open(filename, "r") as file:
            cookies = json.load(file)
            for cookie in cookies:
                driver.add_cookie(cookie)
        print("✅ Cookies loaded.")
    except FileNotFoundError:
        print("⚠️ No cookies found. Proceeding without loading cookies.")

# %%
# ============================
# 🟡 Function: Scroll Down Page
# ============================
def scroll_down(driver, scroll_times=3, delay=1):
    """ Scrolls down the page to load more products dynamically. """
    for _ in range(scroll_times):
        driver.execute_script("window.scrollBy(0, 700);")
        time.sleep(delay)

# %%
# ============================
# 🟡 Function: Extract Product Data from Search Results
# ============================
def extract_products_from_page(driver):
    """
    Extracts product titles, prices, and URLs from the current search results page.
    """
    product_data = []  # Initialize an empty list to store product data
    try:
        # Locate all product items on the page
        products = driver.find_elements(By.XPATH, '//li[contains(@class, "brwrvr__item-card brwrvr__item-card--gallery")]')
        for product in products:  # Iterate through each product element
            try:
                # Extract product title, price, and URL
                title_element = product.find_element(By.XPATH, './/h3[contains(@class, "textual-display bsig__title__text")]')
                price_element = product.find_element(By.XPATH, './/span[contains(@class, "textual-display bsig__price bsig__price--displayprice")]')
                link_element = product.find_element(By.XPATH, './/a[contains(@class, "bsig__title__wrapper")]')

                
                title = title_element.text.strip() if title_element else "N/A"   # Get title text
                price = price_element.text.strip() if price_element else "N/A"   # Get price text
                url = link_element.get_attribute('href') if link_element else "N/A"   # Get product UR
                
                product_data.append({"Title": title, "Price": price, "URL": url})  # Store extracted data
                print(f"📦 Extracted: {title} | {price}")  # Print extracted product info
            except Exception as e:
                print(f"⚠️ Error extracting product data: {e}")  # Handle extraction errors
    except Exception as e:
        print(f"❌ Error extracting products from page: {e}")  # Handle overall extraction errors
    return product_data  # Return extracted product data

# %%
# ============================
# 🟡 Function: Extract All Product Data Across Pages
# ============================
def extract_all_products(driver, max_pages=2):
    """
    Extracts product data across multiple pages.
    """
    all_data = []  # Initialize list to store all product data
    
    for page in range(1, max_pages + 1):   # Loop through the specified number of pages
        print(f"📄 Scraping page {page}...")  # Indicate the current page being scraped

        products = extract_products_from_page(driver)  # Extract products from the current page
        print(f"🔍 Found {len(products)} products on page {page}")  # Display the number of products found
        
        if products:
            all_data.extend(products)  # Add extracted products to the main list
        else:
            print("⚠️ No products found, stopping extraction.")   # Stop extraction if no products found
            break

        try:
            next_button = driver.find_element(By.CSS_SELECTOR, "a.pagination__next")  # Locate the next page button
            driver.execute_script("arguments[0].click();", next_button)  # Click the next page button
            time.sleep(3)  # Ensure the next page loads
        except Exception as e:
            print(f"❌ No more pages or error: {e}")  # Handle pagination errors
            break  # Stop if no more pages are available
    
    print(f"✅ Extracted {len(all_data)} products in total.")
    return all_data  # Return all extracted product data

# %%
# ============================
# 🟡 Function: Search on eBay
# ============================
def search_ebay(driver):
    """
    Opens eBay and waits for the user to perform a search manually.
    """
    try:
        driver.get("https://www.ebay.com/")
        input("🔹 Please go to the search bar and perform a search. Press Enter when you're ready...")
        print("✅ Waiting for you to perform the search...")

        WebDriverWait(driver, 5).until(
            EC.presence_of_element_located((By.ID, "gh-ac"))
        )
        input("🔹 After you've searched, press Enter to continue...")
    except Exception as e:
        print(f"❌ Error during search: {e}")

# %%
# ============================
# 🟡 Main Function
# ============================
def main():
    """ Main function to scrape eBay data. """
    driver = setup_driver()  # Initialize WebDriver
    driver.get("https://www.ebay.com/")  # Open eBay website
    
    input("🔹 Perform a search on eBay and press Enter when ready...")   # Wait for user to perform a search

    # Extract product data from current page and possibly multiple pages
    all_products = extract_all_products(driver, max_pages=2) # Extract products from eBay
    
    # Save data to DataFrame and CSV
    df = pd.DataFrame(all_products)  # Convert extracted data to DataFrame
    df.to_csv("ebay_products.csv", index=False)  # Save data to CSV file
    
    driver.quit()
    print(all_products)
    print("✅ Scraping completed. Data saved to ebay_products.csv")  # Indicate completion

# %%
# ============================
# 🚀 Execute Main Function
# ============================

nest_asyncio.apply()  # Allow nested async loops
asyncio.run(main())   # Run the main function asynchronously
# Out:
# 📄 Scraping page 1...
# 📦 Extracted: Mens VINTAGE Rolex Day-Date President Watch 18k Yellow Gold 36mm | $13,500.00
# 📦 Extracted: Rolex Datejust Custom 4CTW Real Diamond Jubilee 31mm Watch Bracelet | $2,798.00
# 📦 Extracted: OEM ROLEX Oyster Bracelet (2024) Links. New Never Worn. 15.5mm | $85.07
# 📦 Extracted: 100% Genuine Rolex Datejust Watchband Gold Steel Two Tone LINK | $144.44
# 📦 Extracted: ROLEX Vietnam War Military Vintage Watch Hand Rolled Black Dial Used Working | $899.00
# 📦 Extracted: Vintage Rolex Oyster date 6694 Steel & Gold Filled Watch | $1,299.99
# 📦 Extracted: ROLEX MENS DATEJUST BLUE DIAL 18K WHITE GOLD & STAINLESS STEEL WATCH | $4,199.95
# 📦 Extracted: ROLEX MENS DATEJUST GREEN DIAL 18K WHITE GOLD STEEL WATCH w/ JUBILEE BAND | $4,199.95
# 📦 Extracted: ROLEX OYSTER PERPETUAL DATEJUST Ref 1601 Steel Automatic 36mm WrisWatch 1970s | $1,100.00
# 📦 Extracted: Rolex Submariner Date 40mm Steel Black Dial Mens Watch Oyster 16610 | $8,249.99
# 📦 Extracted: Rolex Oyster Perpetual Air King Ref. 5500 Vintage 1972 SS Mens Watch....34mm | $2,995.00
# 📦 Extracted: Rolex Military Vintage Watch White Dial Hand-Rolled Vietnam War | $748.90
# 📦 Extracted: Rolex End Links 555 B , Stainless Steel, New 20mm | $290.00
# 📦 Extracted: ROLEX Precision Cut glass K18WG cal.1400 Silver Dial Hand Winding Ladies_801454 | $977.90
# 📦 Extracted: Vintage Rolex Date Lady Stainless Steel & White Gold Watch Silver Dial 6517 | $2,391.98
# 📦 Extracted: Rolex Datejust Mens Stainless Steel Watch 18K White Gold Bezel Silver Dial 1601 | $3,955.98
# 📦 Extracted: Rolex Submariner 40mm 116610 Green Ceramic Bezel Insert For 116610LV Hulk Mint | $14,990.00
# 📦 Extracted: Rolex Chronograph Blue Dial Men's Wristwatch Vintage 1940s 34mm Manual Winding | $550.00
# 📦 Extracted: Rolex President Day Date 18238 Diamond Dial 18k Yellow Gold Watch | $13,200.00
# 📦 Extracted: Rolex President Day Date 18038 36mm Champagne Diamond Dial 18K Yellow Gold | $13,495.00
# 📦 Extracted: Rolex Mens Datejust 36mm 18k Yellow Gold & Steel ICED 2.25ct Diamonds Black Dial | $6,251.00
# 📦 Extracted: Rolex Men's Datejust 41mm Black Iced Out 10ct Diamonds Oyster Steel Watch 116300 | $12,999.00
# 📦 Extracted: LADIES ROLEX DATE PINK DIAMOND DIAL 18K WHITE GOLD & STAINLESS STEEL WATCH | $4,040.00
# 📦 Extracted: Vintage Rolex Oyster Speedking Manual Winding Movement Mechanical Watch 30mm | $1,200.00
# 📦 Extracted: Unworn 2025 Rolex Datejust 41mm, Fluted Bezel, Mint Green Dial, Jubilee, 126334. | $16,000.00
# 📦 Extracted: Rolex Submariner Kermit 126610LV -0002 Mk II 70th Anniversary Full Set Box&paper | $12,600.00
# 📦 Extracted: Estate $9000 ROLEX DATEJUST Tiffany & Co BLUE SS Ladies Watch SERVICED | $1,194.00
# 📦 Extracted: Rolex Datejust 41mm 18K two tone 116333 Champagne Diamond Dial -Box&Papers+RSC | $11,350.00
# 📦 Extracted: *** Rolex New Old Golf Swag Mens 2XL Event Green Embroidered *** | $220.00
# 📦 Extracted: VINTAGE ROLEX: The world's largest Rolex catalogue Miracle Catalog 9204325056 | $254.73
# 📦 Extracted: Authentic Men's Rolex Oyster Speed king Precision Serrated Bezel Vintage Watch | $770.00
# 📦 Extracted: Rolex Quickset 36MM Stainless Steel Silver Index Fluted Bezel Jubilee Datejust | $6,550.00
# 📦 Extracted: Rolex Submariner Bluesy 16613 Vintage 2000 18k Solid Gold/SS Mens Watch....40mm | $10,895.00
# 📦 Extracted: 1978 Rolex Air-King 5500 Matte Black Dial, W/Box, All Original. Serviced In 2024 | $3,750.00
# 📦 Extracted: Rolex Oyster Perpetual Datejust 18k/SS Ladies 69173 Watch Jubilee Band 1984 | $3,795.00
# 📦 Extracted: Rolex Daytona 16523 Zenith 18k Yellow Two Tone White Dial Men's Watch 40mm | $14,099.00
# 📦 Extracted: Rolex Daytona Cosmograph 40mm 18k/Steel Men's Oyster METEORITE Dial Watch 116523 | $16,999.00
# 📦 Extracted: NEW 2025 Rolex Oyster Perpetual GREEN 277200 Oyster Bracelet with Silver Bezel | $8,200.00
# 📦 Extracted: Vintage Rolex Tudor Caseback 7576 Part | $95.00
# 📦 Extracted: *** Rolex New Old Golf Swag Mens 2XL Event Green Embroidered Cotton *** | $220.00
# 📦 Extracted: Rolex Ladies Datejust 26mm 18kGold & Steel Watch ICED 1.0ct Diamonds White Dial | $4,982.00
# 📦 Extracted: VTG ROLEX MARCONI 35mm Ø GOLD PLATED CASE SILVER DIAL WORKING CIRCA 1930 | $800.00
# 📦 Extracted: Rolex GMT-Master 16700 Swiss - T 25 Dial Vintage 1993 Mens Watch....40mm | $10,985.00
# 📦 Extracted: Ultra Rare Rolex Presidential 18K Yellow Gold Cufflinks | $6,284.42
# 📦 Extracted: Rolex Military Vietnam War Antique Vintage Black Dial Hand Winding Wristwatch | $1,000.00
# 📦 Extracted: Rolex Oyster Perpetual 1505 Date Mens Two-Tone 34mm Watch 7205 Riveted Bracelet | $1,700.00
# 📦 Extracted: Rolex Marconi Vintage Antique White Dial Manual Winding Watch 1930's Old Rolex | $3,699.00
# 📦 Extracted: Rolex Submariner 14060M No Date Engraved Rehaut And Laser Etched Crystal | $8,995.00
# 📦 Extracted: ROLEX VINTAGE SERVICE DIVISION BOXES - MANY AVAILABLE | $22.50
# 📦 Extracted: Rolex Oyster Perpetual 124300 GREEN 41mm BOXES AND PAPERS MINT! | $9,400.00
# 📦 Extracted: Rolex Sky-Dweller Blue Dial Oyster With Box & Papers 2021 Ref 326934 | $20,100.00
# 📦 Extracted: 2007 Rolex Explorer II 16570 Steel Black Dial NO HOLES Automatic Date Watch 40MM | $6,899.00
# 📦 Extracted: ROLEX MENS DATEJUST 16233 18K YELLOW GOLD STAINLESS STEEL DIAMOND WATCH | $7,599.00
# 📦 Extracted: Rolex Datejust 36MM Yellow Gold Tiger Eye Dial Ref. 1601 | $42,995.00
# 📦 Extracted: Rolex Datejust Lady Watch 18K Solid Gold 55.2Grs 26mm Automatic 1980s Ref. 6917 | $4,300.00
# 📦 Extracted: ROLEX Vintage Military Watch Vietnam War Hand-Rolled | $885.00
# 📦 Extracted: LADIES ROLEX DATE DIAMOND SAPPHIRE 18K WHITE GOLD & STEEL BLUE DIAL WATCH | $4,040.00
# 📦 Extracted: Rolex Yacht-Master Reference 16622 SS Platinum Bezel/Dial 2007 Mens Watch...40mm | $8,995.00
# 📦 Extracted: ROLEX Precision vintage cal.1300 Silver Dial Hand Winding Ladies Watch_860986 | $918.00
# 📦 Extracted: [Japan Used Watch] Watchfan Rolex Premium Modern Permanent Preservation Edition | $60.92
# 🔍 Found 60 products on page 1
# 📄 Scraping page 2...
# 📦 Extracted: [Japan Used Watch] Watchfan Rolex Premium Modern Permanent Preservation Edition | $60.92
# 📦 Extracted: Rolex Catalog Black Logo Gold Men's/Women's YDsqvzevgy | $145.02
# 📦 Extracted: Rolex Submariner Date Stainless Steel Watch Black Dial Bezel Mens Sub 16610 | $10,699.98
# 📦 Extracted: Rolex Datejust Custom Diamond Jubilee Band Diamond Dial Bezel Pearl 26mm Watch | $9,299.00
# 📦 Extracted: 2023 Rolex Submariner Date Starbucks Black Dial 41mm 126610LV Box & Papers MINT! | $14,999.00
# 📦 Extracted: 2019 MINT Rolex GMT Master Root Beer Two Tone Rose Gold 126711 Box and Card | $17,800.00
# 📦 Extracted: Rolex Datejust 41 Blue Roman Dial White Gold Bezel 116334 | $11,000.00
# 📦 Extracted: ROLEX OYSTER PERPETUAL DATE 1501 34MM STAINLESS STEEL GREEN DIAL AUTOMATIC WATCH | $3,590.00
# 📦 Extracted: 2007 Rolex Air King 14000M Automatic Watch Stainless Black Dial 34MM | $3,999.00
# 📦 Extracted: 2023 Rolex Oyster Perpetual 124300 Blue Dial SS Oyster With Box And Papers 41mm | $7,500.00
# 📦 Extracted: Rolex Oyster Perpetual Datejust 16234 Stainless Steel 36mm Silver Dial Watch | $1,425.00
# 📦 Extracted: Rolex Oyster Perpetual White Gold bezel! 2023 RSC Service, still under warranty! | $5,500.00
# 📦 Extracted: Mens Rolex Date Stainless Steel Watch Black Leather Strap Band Silver Dial 1500 | $3,449.98
# 📦 Extracted: Rolex Ladies 26mm Datejust White Mother Of Pearl 2 Tone Diamond Original Dial | $250.00
# 📦 Extracted: Rolex Datejust Custom Iced Turquoise Roman Diamond Dial Jubilee Band 36mm Watch | $10,899.00
# 📦 Extracted: ROLEX Precision 2141 vintage K18WG Cal.1401 Hand Winding Ladies Watch D#135463 | $979.30
# 📦 Extracted: ROLEX MENS DATEJUST BLACK DIAL 18K WHITE GOLD BEZEL & STAINLESS STEEL WATCH | $4,199.96
# 📦 Extracted: Rolex Submariner 16613 Blue Dial 2-Tone Steel & Gold Men's Watch Box And Books | $10,975.00
# 📦 Extracted: Rolex Oyster Precision 6426 SS Vintage 1975 Manual Wind Mens Watch....34mm | $3,295.00
# 📦 Extracted: Rolex Submariner 126610LV Silver Oyster Bracelet with Green Bezel | $13,500.00
# 📦 Extracted: $10,000 ROLEX OYSTER PERPETUAL 24mm SS BLACK OPAL DIAMOND Ladies Watch SERVICED | $2,350.00
# 📦 Extracted: Vintage ROLEX Air King 5500 Automatic Oyster Perpetual Watch Rivet Band | $2,649.99
# 📦 Extracted: Rolex Daytona 2008 Two Tone Good Condition With Papers No Box- 116523 | $15,000.00
# 📦 Extracted: ROLEX 16613 SUBMARINER DATE BLUE DIAL TWO-TONE SS 40mm AUTOMATIC WATCH W/ BOX. | $11,500.00
# 📦 Extracted: Rolex GMT-Master II, Batman black/blue ceramic bezel, ref 116710BLNR with box an | $14,750.00
# 📦 Extracted: Rolex Watch 1500 34mm Women's Silver 3270926 | $760.00
# 📦 Extracted: Rolex Datejust 41mm 126334 Rhodium Slate Dial Jubilee Fluted Bezel Box Papers | $13,350.00
# 📦 Extracted: Rolex Datejust 41mm 126334 Fluted Jubilee Wimbledon Dial - Brand New 2024 | $14,500.00
# 📦 Extracted: Wmt Watch Sanford Mkii | $940.00
# 📦 Extracted: Rolex Date 1503 Mens Solid 14K Yellow Gold Watch with Gold Champagne Dial | $11,299.98
# 📦 Extracted: Rolex Men's Datejust II Oyster 41mm Iced Out 20ct Genuine Diamonds Ref:116300 | $17,499.95
# 📦 Extracted: ROLEX YEAR1910 GOOD WORK *WINDING GEAR BROKEN 1 TOOTH NOT AFFECT WORK *READ INFO | $1,500.00
# 📦 Extracted: VINTAGE LADIES WRISTWATCH ROLEX DAYJUST 6917 WHITE DIAL VINTAGE BOX & PAPERS!!! | $3,250.00
# 📦 Extracted: ROLEX MENS DATEJUST 16013 GREEN DIAL 18K GOLD STEEL WATCH w/ BROWN LEATHER BAND | $5,099.00
# 📦 Extracted: ROLEX Oyster Perpetual Datejust 1601 18K-SS Cal. 1560 BUTTERFLY Rotor 36mm 1961 | $1,999.00
# 📦 Extracted: ROLEX GMT-MASTER II 116710LN STEEL 40MM CUSTOM METEORITE DIAL CERAMIC BEZEL-B&P | $14,950.00
# 📦 Extracted: LADIES ROLEX DATEJUST SILVER DIAMOND 18K WHITE GOLD & STAINLESS STEEL WATCH | $4,040.00
# 📦 Extracted: ROLEX MENS BLUE DIAL DATEJUST 18K WHITE GOLD & STAINLESS STEEL AUTHENTIC WATCH | $4,599.95
# 📦 Extracted: Rolex End Links 558 , Stainless Steel, New 20mm | $250.00
# 📦 Extracted: 1947 Vintage Rolex Watch Insert Parts Tin Box Display Dial Container | $79.00
# 📦 Extracted: Protective film for Rolex Sky-Dweller 42 Jubilee 326934 and much more | $47.05
# 📦 Extracted: Rolex 16013 Two Tone, Rare Linen Champagne Dial, CIRCA 1978 RARE | $5,000.00
# 📦 Extracted: Rolex Explorer II 226570 White UNWORN 2025 Polar 42 mm | $12,550.00
# 📦 Extracted: Rolex Yacht-Master 18k Yellow Gold White Dial 40mm Automatic Men’s Watch 16628 | $19,995.00
# 📦 Extracted: ROLEX OYSTER PERPETUAL AIR-KING 5500 STEEL GREEN DIAMOND DIAL 34MM WATCH | $3,590.00
# 📦 Extracted: Rolex Submariner 124060 Black UNWORN 2024 Oyster Steel 41 mm | $12,900.00
# 📦 Extracted: NEW UNWORN 2024 Rolex Day-Date Green Ombre Gradient Yellow Gold 228238-0069 | $57,495.00
# 📦 Extracted: MENS ROLEX DATEJUST 18K WHITE GOLD & STAINLESS STEEL SILVER DIAMOND DIAL WATCH | $4,499.00
# 📦 Extracted: Rolex Datejust Ref.16014 Stainless Steel & White Gold 36mm Celebration Dial | $5,557.50
# 📦 Extracted: Gorgeous 18k And Diamond Dial 31mm Datejust 18k Yellow Gold President 68278 | $14,950.00
# 📦 Extracted: ROLEX LADIES DATEJUST CHAMPAGNE DIAMOND 2 TONE 18K YELLOW GOLD 69173 WATCH | $4,295.00
# 📦 Extracted: ROLEX DATEJUST 31 MOTHER OF PEARL YELLOW GOLD STEEL DIAMOND BEZEL ref: 68273 | $9,500.00
# 📦 Extracted: Rolex GMT Master II Batgirl 126710BLNR Unworn 2024 | $17,995.00
# 📦 Extracted: Rolex Jubilee ICED OUT Datejust 36MM Stainless/10k Gold 16CTW Diamond Mens Watch | $8,999.99
# 📦 Extracted: ROLEX MENS DATEJUST 18K WHITE GOLD BEZEL & STAINLESS STEEL BLACK DIAL WATCH | $4,199.96
# 📦 Extracted: Rolex Oyster Perpetual 25mm Stainless Steel Watch Pink Diamond Dial Ref: 76080 | $2,998.60
# 📦 Extracted: Rolex Day-Date 228235 Rosegold Daydate, President Bracelet Olive Dial 2023 Full | $49,800.00
# 📦 Extracted: Rolex Oyster Date 34mm 6694 Stainless Steel Silver Dial | $2,199.00
# 📦 Extracted: "Permanent Edition Rolex 2019 Summer" Special Feature: Explorer Mania 0944938194 | $89.52
# 📦 Extracted: ROLEX 12325 vintage K9YG/Leather Silver Dial Hand Winding Men's Watch N#134557 | $2,309.30
# 🔍 Found 60 products on page 2
# ✅ Extracted 120 products in total.
# [{'Title': 'Mens VINTAGE Rolex Day-Date President Watch 18k Yellow Gold 36mm', 'Price': '$13,500.00', 'URL': 'https://www.ebay.com/itm/166987649102?itmmeta=01JMQ24MS59K18HKBEEJJYXS49&hash=item26e13d504e:g:ItEAAOSwerlm8gn5&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30mL3hxPrXwtyWC%2FNc4KxGcsXbU4J%2F8O0qB4mcf0dfOESWj4R9JOb0JYFkkJ01IkiSUTWU4nZAi9lM25ODm1oCe%2BLts9YmZ56OnjzBrW8elePQsflQZeXgt8fKWvcRTG1WN%2BS7OJH9CKIDeroNAM64l%2BbwnQdZoxiNcLo4%2BTf81K6%2BdLBfRWgtnKh7t0FpRnEV5XAy%2FfZlfpJMxULluKrpzpLn7mjKP6ntXYQ7AVWZTvZtdqy%2B6cpcX7R20AzsxfRzQZNKyBuC1P8fHwEVC6DwYV%7Ctkp%3ABFBM2syS4qVl'}, {'Title': 'Rolex Datejust Custom 4CTW Real Diamond Jubilee 31mm Watch Bracelet', 'Price': '$2,798.00', 'URL': 'https://www.ebay.com/itm/175376404262?itmmeta=01JMQ24MS5BCBQ00R8BXC77CFH&hash=item28d53f8f26:g:EygAAOSwrfBmRtSq&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30nTFM%2FPrMTzD5OD0LXPLR63VpyWMKt7r%2FRGSfCoS6jc5N0I1ioBWAE77g3TyDQVc3iuwpV4a7N260Ku0Mk6bGdYULmqbhITILXe9BL5IDoMwaIX6%2FCW3bKRt%2FgafV6Lvu2cK2awDZrTc9P59Z2YX28%2F7k8NvRbTB35YczwoB2KTdVyrsPgb9CBq%2Ff8Km9%2Byi%2F7HSOR7tJKlr1deehS%2Fq2VDTrVKj10%2B9BNUReKo4MFIKk4lqDQo1sAZRg9i31tg2YXj%2BQjt9wIhhK52TGR3HeLD%7Ctkp%3ABFBM2syS4qVl'}, {'Title': 'OEM ROLEX Oyster Bracelet (2024) Links. New Never Worn. 15.5mm', 'Price': '$85.07', 'URL': 'https://www.ebay.com/itm/235861984193?itmmeta=01JMQ24MS5E53TTA13PSH3ER1Q&hash=item36ea7843c1:g:HVcAAOSwJmJnVNIq&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30nwgTN75SMffo3UllHrYg1HUeZ3pmW6APDDBVoMOJkDZVZsXlr9NWOzj%2B4JMSP8Vq3BNIZuDFswRhd28HKhhJLAzGzf7oklnj4R91HCATwQxYqBrI9SUADVkgsgPC8sbE2UV1vRiNhf75MuhrSnOMw552UXGUqgtSxrx06VZ%2B5piBipAfcQ3pkmW6fA--xivwja1HU4UuyVwFO4UR4YGS6wPLiF5FhP5%2FJ%2BmJ%2FKHJ%2BvcKr2I9MxtOZuUJALofb3lMoEPFZAchfMdaHRVIDTIlUu%7Ctkp%3ABFBM2syS4qVl'}, {'Title': '100% Genuine Rolex Datejust Watchband Gold Steel Two Tone LINK', 'Price': '$144.44', 'URL': 'https://www.ebay.com/itm/305549528643?itmmeta=01JMQ24MS5VVNNC2T758Y52093&hash=item47242bce43:g:m-4AAOSwd0RmN8~r&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30lrE%2BpLiTX%2BXaWcy3BbwOOMu20sCaFgD8jTkffu%2BskDLBlc23FP471eITdBrCqSwtlfbq7oVGfXWPQmqmgqxnbY16JHXTzLG%2BJlYgIYh1ufBO0a72%2BVpG3hbmqxHHqgWYl9oQ5cbUDpCday7%2ByiqfPLX1M71la%2BQoHM%2BSDIOU9aT45vxkcKqi8rRN0IPixo0yGLMFQoe92DeEL0hfhzfT7WkMGR0sFrL6vOdBUfK0wrj1gkSJkKBWEI6ySUQU%2F7YmOdwyWvIfs22ww%2BxAPskqia%7Ctkp%3ABFBM2syS4qVl'}, {'Title': 'ROLEX Vietnam War Military Vintage Watch Hand Rolled Black Dial Used Working', 'Price': '$899.00', 'URL': 'https://www.ebay.com/itm/235921786365?itmmeta=01JMQ24MS5YHTQMHB9AB3YJ30R&hash=item36ee08c5fd:g:Q7UAAOSwWjlnjcFC&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30lq1smUPuiajtiHlW9lmESS4qEq73G%2FwraMPC7UWfEjCnOko6iPWDGovtQTerl6nwKZwEsVkP50rVct4XcF3hZu%2BsU15BGyTvt4WpVY%2BH7XiSL3TTwZ6gX%2FJNuveAyEMjzi4QLQ8A84Qhh%2FMkjlCJeRHe3dYx4qg8XCDygT7udouXx16WUarc9W8RlYkq%2BciycKCqXBOvTpxW%2FTDVmNEr0ekBe%2Fbwq7sO38j9aiZ9RLFh%2FScQiV73%2FW9disaD9Hk3b153Z0mFguQcp4Dq4vTxSz%7Ctkp%3ABk9SR9rMkuKlZQ'}, {'Title': 'Vintage Rolex Oyster date 6694 Steel & Gold Filled Watch', 'Price': '$1,299.99', 'URL': 'https://www.ebay.com/p/3063320676?iid=356595238314'}, {'Title': 'ROLEX MENS DATEJUST BLUE DIAL 18K WHITE GOLD & STAINLESS STEEL WATCH', 'Price': '$4,199.95', 'URL': 'https://www.ebay.com/p/2329391638?iid=382978851637'}, {'Title': 'ROLEX MENS DATEJUST GREEN DIAL 18K WHITE GOLD STEEL WATCH w/ JUBILEE BAND', 'Price': '$4,199.95', 'URL': 'https://www.ebay.com/itm/386428688469?itmmeta=01JMQ24MS5M8EZ7YR088G0TKVT&hash=item59f8f1d855:g:m5MAAOSwqtBlewtX&itmprp=enc%3AAQAKAAAA4MHg7L1Zz0LA5DYYmRTS30klglyoPomnetCiQR66oK7OTGcLuVRpZ3rXxPh0%2BT%2BL82dIp7uW4LEdozM8aB8ls7bapdPR8bHPnaztOT1DvCLd3v1siL6JGYR%2B%2FV4%2Bqte1E8oBjqa30VWbHmeM9hK0bUjhTaxAem6AyyXsxBnbSGdNNYxopp5vcIs7axphJuNjyzQ%2Fk9c157J4qfmfWEv7Pn1JEs4RxQrGEelMkIs8IErJEC%2B2N4tITqvc1%2BbGn6fFrFClOLblZsYLqtaqBDHAQuH5Wt9tftpuA3e8OASGE98S%7Ctkp%3ABk9SR9rMkuKlZQ'}, {'Title': 'ROLEX OYSTER PERPETUAL DATEJUST Ref 1601 Steel Automatic 36mm WrisWatch 1970s', 'Price': '$1,100.00', 'URL': 'https://www.ebay.com/itm/37600543877 ...
# ✅ Scraping completed. Data saved to ebay_products.csv
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 6
#       1 # ============================
#       2 # 🚀 Execute Main Function
#       3 # ============================
#       5 nest_asyncio.apply()  # Allow nested async loops
# ----> 6 asyncio.run(main())   # Run the main function asynchronously
#
# File c:\Users\parni\AppData\Local\Programs\Python\Python313\Lib\site-packages\nest_asyncio.py:28, in _patch_asyncio.<locals>.run(main, debug)
#      26 loop = asyncio.get_event_loop()
#      27 loop.set_debug(debug)
# ---> 28 task = asyncio.ensure_future(main)
#      29 try:
#      30     return loop.run_until_complete(task)
#
# File c:\Users\parni\AppData\Local\Programs\Python\Python313\Lib\asyncio\tasks.py:742, in ensure_future(coro_or_future, loop)
#     740         should_close = False
#     741     else:
# --> 742         raise TypeError('An asyncio.Future, a coroutine or an awaitable '
#     743                         'is required')
#     745 if loop is None:
#     746     loop = events.get_event_loop()
#
# TypeError: An asyncio.Future, a coroutine or an awaitable is required
